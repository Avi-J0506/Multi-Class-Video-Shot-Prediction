# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/cricket-shots-ipl-2023/pull/32_pbks_dc_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/31_rcb_lsg_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/35_gt_kkr_pull_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/25_kkr_srh_pull_13.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/15_dc_lsg_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/18_mi_rcb_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/35_gt_kkr_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/16_pbks_gt_pull_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/8_pbks_kkr_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/20_rr_lsg_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/5_rr_srh_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/39_rr_rcb_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/2_mi_dc_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/33_mi_csk_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/16_pbks_gt_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/22_csk_rcb_pull_15.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/12_lsg_srh_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/19_dc_kkr_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/28_pbks_srh_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/22_csk_rcb_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/37_lsg_mi_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/2_mi_dc_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/2_mi_dc_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/18_mi_rcb_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/23_pbks_mi_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/23_pbks_mi_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/6_kkr_rcb_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/6_kkr_rcb_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/39_rr_rcb_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/24_gt_rr_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/13_rr_rcb_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/27_rcb_dc_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/34_rr_dc_pull_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/17_csk_srh_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/21_gt_srh_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/22_csk_rcb_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/22_csk_rcb_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/26_lsg_mi_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/39_rr_rcb_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/29_csk_gt_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/13_rr_rcb_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/35_gt_kkr_pull_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/2_mi_dc_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/25_kkr_srh_pull_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/39_rr_rcb_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/34_rr_dc_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/10_gt_dc_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/27_rcb_dc_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/25_kkr_srh_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/34_rr_dc_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/9_rr_mi_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/19_dc_kkr_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/19_dc_kkr_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/5_rr_srh_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/13_rr_rcb_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/37_lsg_mi_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/38_pbks_csk_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/35_gt_kkr_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/30_rr_kkr_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/33_mi_csk_pull_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/14_mi_kkr_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/3_rcb_pbks_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/40_srh_gt_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/29_csk_gt_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/29_csk_gt_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/33_mi_csk_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/31_rcb_lsg_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/19_dc_kkr_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/36_rcb_srh_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/11_pbks_csk_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/6_kkr_rcb_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/16_pbks_gt_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/27_rcb_dc_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/7_csk_lsg_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/10_gt_dc_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/27_rcb_dc_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/3_rcb_pbks_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/35_gt_kkr_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/32_pbks_dc_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/22_csk_rcb_pull_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/8_pbks_kkr_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/22_csk_rcb_pull_13.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/12_lsg_srh_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/20_rr_lsg_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/24_gt_rr_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/34_rr_dc_pull_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/6_kkr_rcb_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/22_csk_rcb_pull_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/25_kkr_srh_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/23_pbks_mi_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/40_srh_gt_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/1_csk_kkr_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/40_srh_gt_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/22_csk_rcb_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/4_lsg_gt_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/17_csk_srh_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/10_gt_dc_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/3_rcb_pbks_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/38_pbks_csk_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/39_rr_rcb_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/38_pbks_csk_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/1_csk_kkr_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/20_rr_lsg_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/16_pbks_gt_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/17_csk_srh_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/37_lsg_mi_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/20_rr_lsg_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/19_dc_kkr_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/25_kkr_srh_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/16_pbks_gt_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/1_csk_kkr_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/28_pbks_srh_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/38_pbks_csk_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/19_dc_kkr_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/21_gt_srh_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/15_dc_lsg_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/22_csk_rcb_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/14_mi_kkr_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/26_lsg_mi_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/35_gt_kkr_pull_13.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/9_rr_mi_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/28_pbks_srh_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/34_rr_dc_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/32_pbks_dc_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/14_mi_kkr_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/6_kkr_rcb_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/9_rr_mi_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/32_pbks_dc_pull_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/5_rr_srh_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/12_lsg_srh_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/4_lsg_gt_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/28_pbks_srh_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/21_gt_srh_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/27_rcb_dc_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/20_rr_lsg_pull_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/13_rr_rcb_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/33_mi_csk_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/21_gt_srh_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/31_rcb_lsg_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/27_rcb_dc_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/3_rcb_pbks_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/40_srh_gt_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/1_csk_kkr_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/33_mi_csk_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/40_srh_gt_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/22_csk_rcb_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/27_rcb_dc_pull_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/30_rr_kkr_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/11_pbks_csk_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/13_rr_rcb_pull_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/3_rcb_pbks_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/21_gt_srh_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/11_pbks_csk_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/23_pbks_mi_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/4_lsg_gt_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/31_rcb_lsg_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/5_rr_srh_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/18_mi_rcb_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/25_kkr_srh_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/37_lsg_mi_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/32_pbks_dc_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/22_csk_rcb_pull_14.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/32_pbks_dc_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/12_lsg_srh_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/3_rcb_pbks_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/30_rr_kkr_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/5_rr_srh_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/31_rcb_lsg_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/24_gt_rr_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/40_srh_gt_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/21_gt_srh_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/16_pbks_gt_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/34_rr_dc_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/35_gt_kkr_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/9_rr_mi_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/28_pbks_srh_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/33_mi_csk_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/14_mi_kkr_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/24_gt_rr_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/14_mi_kkr_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/35_gt_kkr_pull_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/14_mi_kkr_pull_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/7_csk_lsg_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/22_csk_rcb_pull_16.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/3_rcb_pbks_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/26_lsg_mi_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/17_csk_srh_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/21_gt_srh_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/25_kkr_srh_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/29_csk_gt_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/7_csk_lsg_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/12_lsg_srh_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/33_mi_csk_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/25_kkr_srh_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/31_rcb_lsg_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/12_lsg_srh_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/14_mi_kkr_pull_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/40_srh_gt_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/1_csk_kkr_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/38_pbks_csk_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/3_rcb_pbks_pull_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/13_rr_rcb_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/12_lsg_srh_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/34_rr_dc_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/23_pbks_mi_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/22_csk_rcb_pull_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/6_kkr_rcb_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/14_mi_kkr_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/13_rr_rcb_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/26_lsg_mi_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/23_pbks_mi_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/5_rr_srh_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/23_pbks_mi_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/29_csk_gt_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/15_dc_lsg_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/25_kkr_srh_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/16_pbks_gt_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/9_rr_mi_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/25_kkr_srh_pull_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/34_rr_dc_pull_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/22_csk_rcb_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/11_pbks_csk_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/33_mi_csk_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/26_lsg_mi_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/29_csk_gt_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/13_rr_rcb_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/25_kkr_srh_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/9_rr_mi_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/37_lsg_mi_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/16_pbks_gt_pull_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/16_pbks_gt_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/30_rr_kkr_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/20_rr_lsg_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/25_kkr_srh_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/13_rr_rcb_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/2_mi_dc_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/2_mi_dc_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/19_dc_kkr_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/24_gt_rr_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/39_rr_rcb_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/14_mi_kkr_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/35_gt_kkr_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/19_dc_kkr_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/32_pbks_dc_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/33_mi_csk_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/29_csk_gt_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/18_mi_rcb_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/27_rcb_dc_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/21_gt_srh_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/35_gt_kkr_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/39_rr_rcb_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/25_kkr_srh_pull_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/5_rr_srh_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/15_dc_lsg_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/11_pbks_csk_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/17_csk_srh_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/14_mi_kkr_pull_13.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/15_dc_lsg_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/35_gt_kkr_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/38_pbks_csk_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/10_gt_dc_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/34_rr_dc_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/20_rr_lsg_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/24_gt_rr_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/23_pbks_mi_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/40_srh_gt_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/3_rcb_pbks_pull_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/17_csk_srh_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/12_lsg_srh_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/16_pbks_gt_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/7_csk_lsg_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/3_rcb_pbks_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/10_gt_dc_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/37_lsg_mi_pull_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/4_lsg_gt_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/32_pbks_dc_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/35_gt_kkr_pull_16.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/35_gt_kkr_pull_14.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/36_rcb_srh_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/20_rr_lsg_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/34_rr_dc_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/17_csk_srh_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/31_rcb_lsg_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/35_gt_kkr_pull_15.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/28_pbks_srh_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/14_mi_kkr_pull_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/33_mi_csk_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/27_rcb_dc_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/39_rr_rcb_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/9_rr_mi_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/32_pbks_dc_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/19_dc_kkr_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/35_gt_kkr_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/29_csk_gt_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/1_csk_kkr_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/31_rcb_lsg_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/22_csk_rcb_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/14_mi_kkr_pull_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/36_rcb_srh_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/3_rcb_pbks_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/13_rr_rcb_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/35_gt_kkr_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/14_mi_kkr_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/27_rcb_dc_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/20_rr_lsg_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/20_rr_lsg_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/2_mi_dc_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/37_lsg_mi_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/6_kkr_rcb_pull_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/39_rr_rcb_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/32_pbks_dc_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/34_rr_dc_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/18_mi_rcb_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/22_csk_rcb_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/10_gt_dc_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/17_csk_srh_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/7_csk_lsg_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/2_mi_dc_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/6_kkr_rcb_pull_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/4_lsg_gt_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/12_lsg_srh_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/2_mi_dc_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/38_pbks_csk_pull_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/16_pbks_gt_pull_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/37_lsg_mi_pull_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/11_pbks_csk_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/37_lsg_mi_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/21_gt_srh_pull_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/21_gt_srh_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/37_lsg_mi_pull_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/16_pbks_gt_pull_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/34_rr_dc_pull_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/pull/6_kkr_rcb_pull_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/12_lsg_srh_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/32_pbks_dc_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/24_gt_rr_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/20_rr_lsg_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/35_gt_kkr_flick_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/35_gt_kkr_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/2_mi_dc_flick_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/28_pbks_srh_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/13_rr_rcb_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/14_mi_kkr_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/27_rcb_dc_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/5_rr_srh_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/1_csk_kkr_flick_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/10_gt_dc_flick_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/1_csk_kkr_flick_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/30_rr_kkr_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/36_rcb_srh_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/22_csk_rcb_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/1_csk_kkr_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/10_gt_dc_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/32_pbks_dc_flick_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/20_rr_lsg_flick_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/32_pbks_dc_flick_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/13_rr_rcb_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/20_rr_lsg_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/31_rcb_lsg_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/4_lsg_gt_flick_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/24_gt_rr_flick_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/1_csk_kkr_flick_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/11_pbks_csk_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/36_rcb_srh_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/27_rcb_dc_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/26_lsg_mi_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/34_rr_dc_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/21_gt_srh_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/11_pbks_csk_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/33_mi_csk_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/22_csk_rcb_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/9_rr_mi_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/4_lsg_gt_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/10_gt_dc_flick_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/1_csk_kkr_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/23_pbks_mi_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/11_pbks_csk_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/27_rcb_dc_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/39_rr_rcb_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/33_mi_csk_flick_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/13_rr_rcb_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/2_mi_dc_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/22_csk_rcb_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/36_rcb_srh_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/40_srh_gt_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/20_rr_lsg_flick_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/35_gt_kkr_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/36_rcb_srh_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/34_rr_dc_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/7_csk_lsg_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/5_rr_srh_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/8_pbks_kkr_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/8_pbks_kkr_flick_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/35_gt_kkr_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/32_pbks_dc_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/8_pbks_kkr_flick_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/29_csk_gt_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/37_lsg_mi_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/3_rcb_pbks_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/40_srh_gt_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/33_mi_csk_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/19_dc_kkr_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/18_mi_rcb_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/5_rr_srh_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/10_gt_dc_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/4_lsg_gt_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/21_gt_srh_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/26_lsg_mi_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/32_pbks_dc_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/8_pbks_kkr_flick_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/31_rcb_lsg_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/38_pbks_csk_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/25_kkr_srh_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/13_rr_rcb_flick_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/31_rcb_lsg_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/29_csk_gt_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/30_rr_kkr_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/5_rr_srh_flick_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/23_pbks_mi_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/17_csk_srh_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/19_dc_kkr_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/37_lsg_mi_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/10_gt_dc_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/5_rr_srh_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/40_srh_gt_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/10_gt_dc_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/37_lsg_mi_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/33_mi_csk_flick_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/2_mi_dc_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/27_rcb_dc_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/9_rr_mi_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/18_mi_rcb_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/12_lsg_srh_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/29_csk_gt_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/34_rr_dc_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/6_kkr_rcb_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/39_rr_rcb_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/26_lsg_mi_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/2_mi_dc_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/40_srh_gt_flick_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/9_rr_mi_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/30_rr_kkr_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/15_dc_lsg_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/39_rr_rcb_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/8_pbks_kkr_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/13_rr_rcb_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/24_gt_rr_flick_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/35_gt_kkr_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/23_pbks_mi_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/12_lsg_srh_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/13_rr_rcb_flick_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/1_csk_kkr_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/24_gt_rr_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/10_gt_dc_flick_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/33_mi_csk_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/3_rcb_pbks_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/23_pbks_mi_flick_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/7_csk_lsg_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/18_mi_rcb_flick_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/27_rcb_dc_flick_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/11_pbks_csk_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/15_dc_lsg_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/40_srh_gt_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/18_mi_rcb_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/32_pbks_dc_flick_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/20_rr_lsg_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/33_mi_csk_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/4_lsg_gt_flick_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/26_lsg_mi_flick_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/32_pbks_dc_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/39_rr_rcb_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/26_lsg_mi_flick_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/26_lsg_mi_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/8_pbks_kkr_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/17_csk_srh_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/3_rcb_pbks_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/25_kkr_srh_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/8_pbks_kkr_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/24_gt_rr_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/23_pbks_mi_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/29_csk_gt_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/4_lsg_gt_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/18_mi_rcb_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/4_lsg_gt_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/1_csk_kkr_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/37_lsg_mi_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/30_rr_kkr_flick_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/24_gt_rr_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/2_mi_dc_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/36_rcb_srh_flick_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/1_csk_kkr_flick_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/34_rr_dc_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/24_gt_rr_flick_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/20_rr_lsg_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/7_csk_lsg_flick_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/7_csk_lsg_flick_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/12_lsg_srh_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/flick/19_dc_kkr_flick_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/31_rcb_lsg_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/4_lsg_gt_misc_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/24_gt_rr_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/26_lsg_mi_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/27_rcb_dc_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/17_csk_srh_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/6_kkr_rcb_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/27_rcb_dc_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/5_rr_srh_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/14_mi_kkr_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/40_srh_gt_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/18_mi_rcb_misc_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/26_lsg_mi_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/20_rr_lsg_misc_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/39_rr_rcb_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/24_gt_rr_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/25_kkr_srh_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/35_gt_kkr_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/23_pbks_mi_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/5_rr_srh_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/18_mi_rcb_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/33_mi_csk_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/16_pbks_gt_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/29_csk_gt_misc_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/7_csk_lsg_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/15_dc_lsg_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/7_csk_lsg_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/31_rcb_lsg_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/19_dc_kkr_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/14_mi_kkr_misc_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/39_rr_rcb_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/15_dc_lsg_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/11_pbks_csk_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/11_pbks_csk_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/13_rr_rcb_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/22_csk_rcb_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/16_pbks_gt_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/4_lsg_gt_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/29_csk_gt_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/39_rr_rcb_misc_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/39_rr_rcb_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/30_rr_kkr_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/31_rcb_lsg_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/24_gt_rr_misc_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/40_srh_gt_misc_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/34_rr_dc_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/12_lsg_srh_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/37_lsg_mi_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/7_csk_lsg_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/34_rr_dc_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/6_kkr_rcb_misc_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/11_pbks_csk_misc_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/12_lsg_srh_misc_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/29_csk_gt_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/14_mi_kkr_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/18_mi_rcb_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/30_rr_kkr_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/17_csk_srh_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/30_rr_kkr_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/10_gt_dc_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/29_csk_gt_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/17_csk_srh_misc_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/16_pbks_gt_misc_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/16_pbks_gt_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/3_rcb_pbks_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/32_pbks_dc_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/35_gt_kkr_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/12_lsg_srh_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/31_rcb_lsg_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/33_mi_csk_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/31_rcb_lsg_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/17_csk_srh_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/29_csk_gt_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/17_csk_srh_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/18_mi_rcb_misc_15.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/20_rr_lsg_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/11_pbks_csk_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/35_gt_kkr_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/13_rr_rcb_misc_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/24_gt_rr_misc_14.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/17_csk_srh_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/4_lsg_gt_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/19_dc_kkr_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/17_csk_srh_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/33_mi_csk_misc_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/27_rcb_dc_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/2_mi_dc_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/12_lsg_srh_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/39_rr_rcb_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/20_rr_lsg_misc_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/39_rr_rcb_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/21_gt_srh_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/20_rr_lsg_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/14_mi_kkr_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/22_csk_rcb_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/11_pbks_csk_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/35_gt_kkr_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/12_lsg_srh_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/3_rcb_pbks_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/2_mi_dc_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/5_rr_srh_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/25_kkr_srh_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/24_gt_rr_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/40_srh_gt_misc_14.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/40_srh_gt_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/24_gt_rr_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/7_csk_lsg_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/32_pbks_dc_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/33_mi_csk_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/35_gt_kkr_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/25_kkr_srh_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/23_pbks_mi_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/33_mi_csk_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/1_csk_kkr_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/39_rr_rcb_misc_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/34_rr_dc_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/16_pbks_gt_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/13_rr_rcb_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/28_pbks_srh_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/4_lsg_gt_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/27_rcb_dc_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/9_rr_mi_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/1_csk_kkr_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/32_pbks_dc_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/16_pbks_gt_misc_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/9_rr_mi_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/14_mi_kkr_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/11_pbks_csk_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/16_pbks_gt_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/19_dc_kkr_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/3_rcb_pbks_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/33_mi_csk_misc_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/31_rcb_lsg_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/8_pbks_kkr_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/36_rcb_srh_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/26_lsg_mi_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/26_lsg_mi_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/32_pbks_dc_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/21_gt_srh_misc_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/20_rr_lsg_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/14_mi_kkr_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/34_rr_dc_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/20_rr_lsg_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/22_csk_rcb_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/17_csk_srh_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/29_csk_gt_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/28_pbks_srh_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/12_lsg_srh_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/40_srh_gt_misc_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/6_kkr_rcb_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/23_pbks_mi_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/30_rr_kkr_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/26_lsg_mi_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/24_gt_rr_misc_13.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/23_pbks_mi_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/21_gt_srh_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/8_pbks_kkr_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/4_lsg_gt_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/27_rcb_dc_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/16_pbks_gt_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/40_srh_gt_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/37_lsg_mi_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/17_csk_srh_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/8_pbks_kkr_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/21_gt_srh_misc_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/18_mi_rcb_misc_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/28_pbks_srh_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/27_rcb_dc_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/22_csk_rcb_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/37_lsg_mi_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/15_dc_lsg_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/29_csk_gt_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/8_pbks_kkr_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/14_mi_kkr_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/27_rcb_dc_misc_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/15_dc_lsg_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/38_pbks_csk_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/20_rr_lsg_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/31_rcb_lsg_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/33_mi_csk_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/28_pbks_srh_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/34_rr_dc_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/40_srh_gt_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/6_kkr_rcb_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/23_pbks_mi_misc_13.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/5_rr_srh_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/23_pbks_mi_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/19_dc_kkr_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/15_dc_lsg_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/39_rr_rcb_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/2_mi_dc_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/25_kkr_srh_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/24_gt_rr_misc_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/39_rr_rcb_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/36_rcb_srh_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/6_kkr_rcb_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/4_lsg_gt_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/37_lsg_mi_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/1_csk_kkr_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/30_rr_kkr_misc_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/35_gt_kkr_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/20_rr_lsg_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/30_rr_kkr_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/21_gt_srh_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/19_dc_kkr_misc_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/16_pbks_gt_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/32_pbks_dc_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/32_pbks_dc_misc_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/34_rr_dc_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/30_rr_kkr_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/26_lsg_mi_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/35_gt_kkr_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/18_mi_rcb_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/28_pbks_srh_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/1_csk_kkr_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/26_lsg_mi_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/13_rr_rcb_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/6_kkr_rcb_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/23_pbks_mi_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/27_rcb_dc_misc_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/15_dc_lsg_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/17_csk_srh_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/38_pbks_csk_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/40_srh_gt_misc_13.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/9_rr_mi_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/23_pbks_mi_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/3_rcb_pbks_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/37_lsg_mi_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/13_rr_rcb_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/29_csk_gt_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/22_csk_rcb_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/20_rr_lsg_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/15_dc_lsg_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/26_lsg_mi_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/13_rr_rcb_misc_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/6_kkr_rcb_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/11_pbks_csk_misc_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/10_gt_dc_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/13_rr_rcb_misc_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/18_mi_rcb_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/18_mi_rcb_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/10_gt_dc_misc_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/28_pbks_srh_misc_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/24_gt_rr_misc_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/40_srh_gt_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/18_mi_rcb_misc_16.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/32_pbks_dc_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/40_srh_gt_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/19_dc_kkr_misc_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/18_mi_rcb_misc_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/23_pbks_mi_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/38_pbks_csk_misc_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/33_mi_csk_misc_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/35_gt_kkr_misc_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/misc/24_gt_rr_misc_4.mp4
# ...
# /kaggle/input/cricket-shots-ipl-2023/drive/1_csk_kkr_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/20_rr_lsg_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/26_lsg_mi_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/9_rr_mi_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/16_pbks_gt_drive_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/2_mi_dc_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/25_kkr_srh_drive_13.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/13_rr_rcb_drive_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/13_rr_rcb_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/14_mi_kkr_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/6_kkr_rcb_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/3_rcb_pbks_drive_15.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/28_pbks_srh_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/25_kkr_srh_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/28_pbks_srh_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/31_rcb_lsg_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/39_rr_rcb_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/17_csk_srh_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/9_rr_mi_drive_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/32_pbks_dc_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/30_rr_kkr_drive_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/25_kkr_srh_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/16_pbks_gt_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/3_rcb_pbks_drive_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/12_lsg_srh_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/38_pbks_csk_drive_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/34_rr_dc_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/37_lsg_mi_drive_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/2_mi_dc_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/32_pbks_dc_drive_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/11_pbks_csk_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/38_pbks_csk_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/24_gt_rr_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/40_srh_gt_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/23_pbks_mi_drive_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/12_lsg_srh_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/38_pbks_csk_drive_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/27_rcb_dc_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/7_csk_lsg_drive_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/4_lsg_gt_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/21_gt_srh_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/15_dc_lsg_drive_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/2_mi_dc_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/26_lsg_mi_drive_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/23_pbks_mi_drive_14.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/38_pbks_csk_drive_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/1_csk_kkr_drive_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/23_pbks_mi_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/16_pbks_gt_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/9_rr_mi_drive_13.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/26_lsg_mi_drive_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/13_rr_rcb_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/39_rr_rcb_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/13_rr_rcb_drive_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/9_rr_mi_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/17_csk_srh_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/23_pbks_mi_drive_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/11_pbks_csk_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/4_lsg_gt_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/7_csk_lsg_drive_14.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/28_pbks_srh_drive_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/31_rcb_lsg_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/6_kkr_rcb_drive_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/16_pbks_gt_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/7_csk_lsg_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/11_pbks_csk_drive_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/36_rcb_srh_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/11_pbks_csk_drive_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/17_csk_srh_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/8_pbks_kkr_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/16_pbks_gt_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/7_csk_lsg_drive_13.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/37_lsg_mi_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/6_kkr_rcb_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/29_csk_gt_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/33_mi_csk_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/38_pbks_csk_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/11_pbks_csk_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/7_csk_lsg_drive_16.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/27_rcb_dc_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/15_dc_lsg_drive_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/8_pbks_kkr_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/38_pbks_csk_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/2_mi_dc_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/26_lsg_mi_drive_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/1_csk_kkr_drive_13.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/21_gt_srh_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/23_pbks_mi_drive_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/25_kkr_srh_drive_14.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/35_gt_kkr_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/36_rcb_srh_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/37_lsg_mi_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/7_csk_lsg_drive_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/16_pbks_gt_drive_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/15_dc_lsg_drive_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/26_lsg_mi_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/30_rr_kkr_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/5_rr_srh_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/33_mi_csk_drive_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/39_rr_rcb_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/13_rr_rcb_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/1_csk_kkr_drive_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/16_pbks_gt_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/8_pbks_kkr_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/7_csk_lsg_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/3_rcb_pbks_drive_13.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/32_pbks_dc_drive_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/3_rcb_pbks_drive_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/9_rr_mi_drive_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/4_lsg_gt_drive_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/28_pbks_srh_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/2_mi_dc_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/7_csk_lsg_drive_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/13_rr_rcb_drive_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/39_rr_rcb_drive_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/17_csk_srh_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/16_pbks_gt_drive_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/27_rcb_dc_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/11_pbks_csk_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/23_pbks_mi_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/30_rr_kkr_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/13_rr_rcb_drive_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/19_dc_kkr_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/3_rcb_pbks_drive_16.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/36_rcb_srh_drive_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/1_csk_kkr_drive_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/15_dc_lsg_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/30_rr_kkr_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/1_csk_kkr_drive_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/11_pbks_csk_drive_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/29_csk_gt_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/21_gt_srh_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/23_pbks_mi_drive_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/12_lsg_srh_drive_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/32_pbks_dc_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/8_pbks_kkr_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/24_gt_rr_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/22_csk_rcb_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/24_gt_rr_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/11_pbks_csk_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/3_rcb_pbks_drive_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/39_rr_rcb_drive_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/10_gt_dc_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/9_rr_mi_drive_15.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/9_rr_mi_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/26_lsg_mi_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/33_mi_csk_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/25_kkr_srh_drive_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/26_lsg_mi_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/34_rr_dc_drive_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/10_gt_dc_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/3_rcb_pbks_drive_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/30_rr_kkr_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/9_rr_mi_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/33_mi_csk_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/11_pbks_csk_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/35_gt_kkr_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/35_gt_kkr_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/36_rcb_srh_drive_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/25_kkr_srh_drive_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/28_pbks_srh_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/25_kkr_srh_drive_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/34_rr_dc_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/15_dc_lsg_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/24_gt_rr_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/28_pbks_srh_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/6_kkr_rcb_drive_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/23_pbks_mi_drive_13.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/18_mi_rcb_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/36_rcb_srh_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/31_rcb_lsg_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/40_srh_gt_drive_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/31_rcb_lsg_drive_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/1_csk_kkr_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/40_srh_gt_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/39_rr_rcb_drive_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/2_mi_dc_drive_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/13_rr_rcb_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/39_rr_rcb_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/23_pbks_mi_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/28_pbks_srh_drive_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/40_srh_gt_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/5_rr_srh_drive_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/27_rcb_dc_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/40_srh_gt_drive_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/38_pbks_csk_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/7_csk_lsg_drive_17.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/31_rcb_lsg_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/23_pbks_mi_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/36_rcb_srh_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/36_rcb_srh_drive_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/24_gt_rr_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/12_lsg_srh_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/33_mi_csk_drive_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/37_lsg_mi_drive_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/6_kkr_rcb_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/36_rcb_srh_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/15_dc_lsg_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/30_rr_kkr_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/38_pbks_csk_drive_13.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/2_mi_dc_drive_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/32_pbks_dc_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/3_rcb_pbks_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/17_csk_srh_drive_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/31_rcb_lsg_drive_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/14_mi_kkr_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/33_mi_csk_drive_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/33_mi_csk_drive_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/4_lsg_gt_drive_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/27_rcb_dc_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/40_srh_gt_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/7_csk_lsg_drive_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/7_csk_lsg_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/26_lsg_mi_drive_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/6_kkr_rcb_drive_9.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/10_gt_dc_drive_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/37_lsg_mi_drive_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/13_rr_rcb_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/40_srh_gt_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/12_lsg_srh_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/24_gt_rr_drive_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/34_rr_dc_drive_2.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/4_lsg_gt_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/12_lsg_srh_drive_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/29_csk_gt_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/1_csk_kkr_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/2_mi_dc_drive_11.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/26_lsg_mi_drive_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/17_csk_srh_drive_12.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/7_csk_lsg_drive_15.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/38_pbks_csk_drive_4.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/3_rcb_pbks_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/25_kkr_srh_drive_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/2_mi_dc_drive_8.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/3_rcb_pbks_drive_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/12_lsg_srh_drive_10.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/7_csk_lsg_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/38_pbks_csk_drive_7.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/30_rr_kkr_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/13_rr_rcb_drive_6.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/15_dc_lsg_drive_5.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/25_kkr_srh_drive_1.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/18_mi_rcb_drive_3.mp4
# /kaggle/input/cricket-shots-ipl-2023/drive/33_mi_csk_drive_8.mp4

# %%
import os
import shutil

folder_path = "/kaggle/working"

# Iterate and remove each item in the directory
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    try:
        if os.path.isfile(file_path) or os.path.islink(file_path):
            os.remove(file_path)
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)
    except Exception as e:
        print(f"Failed to delete {file_path}. Reason: {e}")

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.10/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /opt/conda/lib/python3.10/site-packages (from opencv-python) (1.26.4)

# %%
import cv2
import os

def extract_frames(video_path, output_folder, frame_interval=1, max_images=500):
    cap = cv2.VideoCapture(video_path)
    frame_count = 0
    saved_count = 0
    success, frame = cap.read()

    os.makedirs(output_folder, exist_ok=True)
    
    while success and saved_count < max_images:
        if frame_count % frame_interval == 0:
            frame_path = os.path.join(output_folder, f"{os.path.basename(video_path).split('.')[0]}_frame_{frame_count}.jpg")
            cv2.imwrite(frame_path, frame)
            saved_count += 1
        
        success, frame = cap.read()
        frame_count += 1
    
    cap.release()
    return saved_count

shots = ['cut', 'drive', 'flick', 'misc', 'pull', 'slog', 'sweep']
total_images = 0
frame_interval = 1  
max_images_per_shot = 500  # Set a maximum of 500 images per shot

for shot in shots:
    video_folder = f'/kaggle/input/cricket-shots-ipl-2023/{shot}'
    output_folder = f'/kaggle/working/images/{shot}_shots/'
    
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    else:
        for f in os.listdir(output_folder):
            os.remove(os.path.join(output_folder, f))
    
    images_generated_for_shot = 0
    for video_file in os.listdir(video_folder):
        video_path = os.path.join(video_folder, video_file)
        images_from_video = extract_frames(video_path, output_folder, frame_interval, max_images=max_images_per_shot - images_generated_for_shot)
        
        images_generated_for_shot += images_from_video
        total_images += images_from_video
        
        # Stop processing if we've reached the limit of 500 images for this shot
        if images_generated_for_shot >= max_images_per_shot:
            break

print(f"Total images generated: {total_images}")
# Out:
# Total images generated: 3500

# %%
import torch

model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

for shot in shots:
    frame_dir = f'/kaggle/working/images/{shot}_shots/'
    label_dir = f'/kaggle/working/labels/{shot}_shots/'
    
    os.makedirs(label_dir, exist_ok=True)
    
    for frame_name in os.listdir(frame_dir):
        img_path = os.path.join(frame_dir, frame_name)
        
        results = model(img_path)
        
        for detection in results.xywh[0]:
            x_center, y_center, width, height, confidence, class_id = detection.tolist()
            if class_id == 0:
                annotation_path = os.path.join(label_dir, f"{frame_name.split('.')[0]}.txt")
                with open(annotation_path, 'w') as f:
                    f.write(f"{shots.index(shot)} {x_center} {y_center} {width} {height}\n")
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/hub.py:295: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# Collecting ultralytics
#   Downloading ultralytics-8.3.24-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.4.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.19.0)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ultralytics) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.12.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.9-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.3.24-py3-none-any.whl (877 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.7/877.7 kB 16.4 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.9-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.24 ultralytics-thop-2.0.9
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLOv5 🚀 2024-10-29 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 127MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):

# %%
import shutil
import random

split_ratio = 0.8

for shot in shots:
    source_dir = f'/kaggle/working/images/{shot}_shots/'
    train_dir = f'/kaggle/working/images/{shot}_shots/train/'
    val_dir = f'/kaggle/working/images/{shot}_shots/val/'

    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)
    
    all_images = [f for f in os.listdir(source_dir) if f.endswith(('.jpg', '.png'))]
    random.shuffle(all_images)
    
    split_index = int(len(all_images) * split_ratio)
    train_images = all_images[:split_index]
    val_images = all_images[split_index:]

    for img in train_images:
        shutil.move(os.path.join(source_dir, img), os.path.join(train_dir, img))
    
    for img in val_images:
        shutil.move(os.path.join(source_dir, img), os.path.join(val_dir, img))
    
    print(f"{shot.capitalize()} - Moved {len(train_images)} images to training set and {len(val_images)} images to validation set.")
# Out:
# Cut - Moved 400 images to training set and 100 images to validation set.
# Drive - Moved 400 images to training set and 100 images to validation set.
# Flick - Moved 400 images to training set and 100 images to validation set.
# Misc - Moved 400 images to training set and 100 images to validation set.
# Pull - Moved 400 images to training set and 100 images to validation set.
# Slog - Moved 400 images to training set and 100 images to validation set.
# Sweep - Moved 400 images to training set and 100 images to validation set.

# %%
for shot in shots:
    source_labels_dir = f'/kaggle/working/labels/{shot}_shots/'
    train_labels_dir = f'/kaggle/working/labels/{shot}_shots/train/'
    val_labels_dir = f'/kaggle/working/labels/{shot}_shots/val/'

    os.makedirs(train_labels_dir, exist_ok=True)
    os.makedirs(val_labels_dir, exist_ok=True)

    train_images = [f for f in os.listdir(f'/kaggle/working/images/{shot}_shots/train/') if f.endswith(('.jpg', '.png'))]

    for img in train_images:
        label_file = os.path.splitext(img)[0] + '.txt'
        if os.path.isfile(os.path.join(source_labels_dir, label_file)):
            shutil.move(os.path.join(source_labels_dir, label_file), os.path.join(train_labels_dir, label_file))
        else:
            print(f"Label file not found for: {img}")

    val_images = [f for f in os.listdir(f'/kaggle/working/images/{shot}_shots/val/') if f.endswith(('.jpg', '.png'))]

    for img in val_images:
        label_file = os.path.splitext(img)[0] + '.txt'
        if os.path.isfile(os.path.join(source_labels_dir, label_file)):
            shutil.move(os.path.join(source_labels_dir, label_file), os.path.join(val_labels_dir, label_file))
        else:
            print(f"Label file not found for: {img}")

    print(f"{shot.capitalize()} - Labels have been moved to the respective train and validation directories.")
# Out:
# Cut - Labels have been moved to the respective train and validation directories.
# Drive - Labels have been moved to the respective train and validation directories.
# Flick - Labels have been moved to the respective train and validation directories.
# Misc - Labels have been moved to the respective train and validation directories.
# Pull - Labels have been moved to the respective train and validation directories.
# Slog - Labels have been moved to the respective train and validation directories.
# Sweep - Labels have been moved to the respective train and validation directories.

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17022, done.
# remote: Total 17022 (delta 0), reused 0 (delta 0), pack-reused 17022 (from 1)
# Receiving objects: 100% (17022/17022), 15.62 MiB | 25.92 MiB/s, done.
# Resolving deltas: 100% (11695/11695), done.

# %%
# !pip install -r yolov5/requirements.txt
# Out:
# Requirement already satisfied: gitpython>=3.1.30 in /opt/conda/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 5)) (3.1.43)
# Requirement already satisfied: matplotlib>=3.3 in /opt/conda/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 6)) (3.7.5)
# Requirement already satisfied: numpy>=1.23.5 in /opt/conda/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 8)) (4.10.0.84)
# Requirement already satisfied: pillow>=10.3.0 in /opt/conda/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 9)) (10.3.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 10)) (5.9.3)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 13)) (1.14.1)
# Collecting thop>=0.1.1 (from -r yolov5/requirements.txt (line 14))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 15)) (2.4.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 16)) (0.19.0)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/conda/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 17)) (4.66.4)
# Requirement already satisfied: ultralytics>=8.2.34 in /opt/conda/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 18)) (8.3.24)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 27)) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 28)) (0.12.2)
# Requirement already satisfied: setuptools>=70.0.0 in /opt/conda/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 42)) (70.0.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython>=3.1.30->-r yolov5/requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->-r yolov5/requirements.txt (line 12)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->-r yolov5/requirements.txt (line 12)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->-r yolov5/requirements.txt (line 12)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->-r yolov5/requirements.txt (line 12)) (2024.8.30)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (2024.6.1)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics>=8.2.34->-r yolov5/requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics>=8.2.34->-r yolov5/requirements.txt (line 18)) (2.0.9)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 27)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 27)) (2024.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r yolov5/requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (1.3.0)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Installing collected packages: thop
# Successfully installed thop-0.1.1.post2209072238

# %%
data_yaml = f'''
train: /kaggle/working/images
val: /kaggle/working/images

nc: 7
names:
  0: cut
  1: drive
  2: flick
  3: misc
  4: pull
  5: slog
  6: sweep
'''

# %%
with open('/kaggle/working/cricket_shots.yaml', 'w') as f:
    f.write(data_yaml)

# %%
# !rm -rf /kaggle/working/images/train.cache
# !rm -rf /kaggle/working/images/val.cache

# %%
import os
import cv2

def normalize_bounding_boxes(image_path, label_path):
    # Load image to get dimensions
    image = cv2.imread(image_path)
    h, w, _ = image.shape

    with open(label_path, 'r') as file:
        lines = file.readlines()

    normalized_lines = []
    for line in lines:
        class_id, x_center, y_center, width, height = map(float, line.strip().split())
        
        # Convert absolute coordinates to normalized values (0 to 1)
        x_center /= w
        y_center /= h
        width /= w
        height /= h

        if 0 <= x_center <= 1 and 0 <= y_center <= 1 and 0 <= width <= 1 and 0 <= height <= 1:
            normalized_lines.append(f"{int(class_id)} {x_center} {y_center} {width} {height}\n")
        else:
            print(f"Warning: Skipped out-of-bounds bounding box in {label_path}")

    with open(label_path, 'w') as file:
        file.writelines(normalized_lines)

def process_all_labels(shots):
    for shot in shots:
        image_dir_train = f'/kaggle/working/images/{shot}_shots/train'
        label_dir_train = f'/kaggle/working/labels/{shot}_shots/train'
        image_dir_val = f'/kaggle/working/images/{shot}_shots/val'
        label_dir_val = f'/kaggle/working/labels/{shot}_shots/val'
        
        # Process training labels
        for img_file in os.listdir(image_dir_train):
            if img_file.endswith('.jpg'):
                img_path = os.path.join(image_dir_train, img_file)
                label_path = os.path.join(label_dir_train, img_file.replace('.jpg', '.txt'))
                
                if os.path.exists(label_path):
                    normalize_bounding_boxes(img_path, label_path)

        # Process validation labels
        for img_file in os.listdir(image_dir_val):
            if img_file.endswith('.jpg'):
                img_path = os.path.join(image_dir_val, img_file)
                label_path = os.path.join(label_dir_val, img_file.replace('.jpg', '.txt'))
                
                if os.path.exists(label_path):
                    normalize_bounding_boxes(img_path, label_path)

# List of all shot categories
shots = ['cut', 'drive', 'flick', 'misc', 'pull', 'slog', 'sweep']

# Process all labels for the specified shots
process_all_labels(shots)

# %%
# !python yolov5/train.py --img 640 --batch 16 --epochs 20 --data /kaggle/working/cricket_shots.yaml --weights yolov5/yolov5s.pt --cache --name cricket_shots_training
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# train: weights=yolov5/yolov5s.pt, cfg=, data=/kaggle/working/cricket_shots.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=yolov5/data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=cricket_shots_training, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-378-g2f74455a Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir yolov5/runs/train', view at http://localhost:6006/
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 14.0MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5/yolov5s.pt...
# 100%|███████████████████████████████████████| 14.1M/14.1M [00:00<00:00, 138MB/s]
#
# Overriding model.yaml nc=80 with nc=7
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     32364  models.yolo.Detect                      [7, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7038508 parameters, 7038508 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5/yolov5s.pt
# /kaggle/working/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /kaggle/working/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# WARNING ⚠️ DP not recommended, use torch.distributed.run for best DDP Multi-GPU results.
# See Multi-GPU Tutorial at https://docs.ultralytics.com/yolov5/tutorials/multi_gpu_training to get started.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# train: Scanning /kaggle/working/labels/cut_shots/train... 3500 images, 0 backgro
# train: New cache created: /kaggle/working/labels/cut_shots/train.cache
# train: Caching images (2.3GB ram): 100%|██████████| 3500/3500 [00:09<00:00, 383.
# val: Scanning /kaggle/working/labels/cut_shots/train.cache... 3500 images, 0 bac
# val: Caching images (2.3GB ram): 100%|██████████| 3500/3500 [00:09<00:00, 382.65
#
# AutoAnchor: 5.66 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to yolov5/runs/train/cricket_shots_training/labels.jpg...
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /kaggle/working/yolov5/train.py:355: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to yolov5/runs/train/cricket_shots_training
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/219 [00:00<?, ?it/s]/kaggle/working/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
#        0/19      1.86G      0.122    0.02753    0.06009         30        640:  /kaggle/working/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
#        0/19      1.92G     0.1234    0.02651    0.06096         24        640:  /kaggle/working/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
#        0/19      1.92G     0.1246    0.02675    0.06133         36        640:  /kaggle/working/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
#        0/19      1.92G     0.1252    0.02629    0.06121         26        640:  /kaggle/working/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
#        0/19      1.92G    0.07118    0.02409    0.05665         31        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500    0.00335      0.966     0.0217     0.0102
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/19      2.39G    0.04657    0.01966    0.05435         24        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500     0.0603      0.286     0.0537     0.0272
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/19      2.39G    0.04235    0.01732     0.0538         16        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500      0.091      0.197     0.0759     0.0433
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/19      2.39G    0.03766     0.0162     0.0532         21        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500     0.0996       0.29     0.0871     0.0513
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/19      2.39G    0.03441    0.01578    0.05257         20        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500      0.102      0.263     0.0988     0.0628
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/19      2.39G    0.03249    0.01565    0.05162         30        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500      0.108      0.283       0.11     0.0763
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/19      2.39G    0.03043    0.01508    0.05034         26        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500      0.127      0.379      0.134     0.0953
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/19      2.39G    0.02785    0.01479    0.04891         18        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500      0.136       0.43      0.159      0.109
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/19      2.39G    0.02727    0.01476    0.04741         18        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500      0.133      0.438      0.159      0.115
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/19      2.39G    0.02682    0.01459    0.04599         23        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500      0.176      0.373      0.199      0.146
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/19      2.39G    0.02574    0.01437    0.04487         22        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500      0.197      0.384      0.227      0.163
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/19      2.39G    0.02475    0.01466    0.04208         19        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500      0.207      0.386      0.234       0.17
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/19      2.39G    0.02406    0.01426    0.04091         28        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500      0.218      0.395      0.255      0.192
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/19      2.39G    0.02398     0.0142    0.03883         22        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500      0.274      0.435      0.334      0.255
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/19      2.39G    0.02304    0.01419    0.03688         17        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500      0.301      0.448      0.338      0.262
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/19      2.39G    0.02278    0.01408     0.0344         24        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500      0.317      0.476      0.397      0.305
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/19      2.39G    0.02197    0.01374    0.03259         13        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500      0.417      0.491      0.433      0.343
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/19      2.39G     0.0215    0.01336    0.02989         18        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500      0.409      0.547       0.46      0.366
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/19      2.39G    0.02082    0.01365    0.02771         23        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500      0.435      0.604      0.518      0.424
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/19      2.39G    0.02027    0.01322    0.02538         23        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500      0.465      0.593      0.537      0.438
#
# 20 epochs completed in 0.489 hours.
# Optimizer stripped from yolov5/runs/train/cricket_shots_training/weights/last.pt, 14.4MB
# Optimizer stripped from yolov5/runs/train/cricket_shots_training/weights/best.pt, 14.4MB
#
# Validating yolov5/runs/train/cricket_shots_training/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7029004 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all       3500       3500      0.464      0.594      0.537      0.438
#                    cut       3500        500      0.385      0.504      0.454      0.378
#                  drive       3500        500      0.553      0.827      0.731      0.593
#                  flick       3500        500      0.384      0.086      0.238      0.184
#                   misc       3500        500      0.551        0.6      0.591      0.486
#                   pull       3500        500      0.421      0.504      0.408      0.342
#                   slog       3500        500      0.428      0.788      0.637      0.534
#                  sweep       3500        500      0.524      0.846      0.696      0.552
# Results saved to yolov5/runs/train/cricket_shots_training

# %%
import torch
import os

# Load the trained model
model = torch.hub.load('ultralytics/yolov5', 'custom', path='/kaggle/working/yolov5/runs/train/cricket_shots_training/weights/best.pt')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Define shots and initialize evaluation metrics
shots = ['cut', 'drive', 'flick', 'misc', 'pull', 'slog', 'sweep']
all_detections = []
all_ground_truths = []

# Loop through each shot type
for shot in shots:
    # Define paths for validation images and labels for each shot
    val_images_dir = f'/kaggle/working/images/{shot}_shots/val/'
    val_labels_dir = f'/kaggle/working/labels/{shot}_shots/val/'

    # Iterate over each image in the validation folder for the shot type
    for image_file in os.listdir(val_images_dir):
        img_path = os.path.join(val_images_dir, image_file)
        results = model(img_path)

        # Load corresponding ground truth labels
        label_file = os.path.join(val_labels_dir, os.path.splitext(image_file)[0] + '.txt')
        if not os.path.exists(label_file):
            continue

        ground_truth_boxes = []
        with open(label_file, 'r') as f:
            for line in f.readlines():
                class_id, x_center, y_center, width, height = map(float, line.strip().split())
                ground_truth_boxes.append([class_id, x_center, y_center, width, height])

        # Convert detections and ground truth to tensor
        detections = results.xyxy[0]  # xyxy format (x1, y1, x2, y2, confidence, class)
        detections = detections.cpu().numpy() if torch.cuda.is_available() else detections.numpy()

        # Append detections and ground truths for evaluation
        all_detections.append(detections)
        all_ground_truths.append(ground_truth_boxes)

# Now, evaluate metrics manually (e.g., precision, recall, and mAP)
def calculate_metrics(detections, ground_truths, iou_threshold=0.5):
    true_positives = 0
    false_positives = 0
    false_negatives = 0

    # Loop through each detection and ground truth pair
    for dets, gts in zip(detections, ground_truths):
        for det in dets:
            x1, y1, x2, y2, conf, class_id = det
            best_iou = 0
            best_gt = None

            # Check against ground truths
            for gt in gts:
                gt_class_id, gt_xc, gt_yc, gt_width, gt_height = gt
                # Convert ground truth from center format to corner format
                gt_x1 = gt_xc - gt_width / 2
                gt_y1 = gt_yc - gt_height / 2
                gt_x2 = gt_xc + gt_width / 2
                gt_y2 = gt_yc + gt_height / 2

                # Calculate IoU
                inter_x1 = max(x1, gt_x1)
                inter_y1 = max(y1, gt_y1)
                inter_x2 = min(x2, gt_x2)
                inter_y2 = min(y2, gt_y2)
                intersection = max(0, inter_x2 - inter_x1) * max(0, inter_y2 - inter_y1)
                union = (x2 - x1) * (y2 - y1) + (gt_x2 - gt_x1) * (gt_y2 - gt_y1) - intersection
                iou = intersection / union if union > 0 else 0

                # Check if it's the best IoU
                if iou > best_iou:
                    best_iou = iou
                    best_gt = gt

            # Determine if the detection is a true positive or false positive
            if best_iou >= iou_threshold and best_gt is not None:
                true_positives += 1
            else:
                false_positives += 1

        # Count false negatives
        false_negatives += len(gts) - true_positives

    # Calculate precision and recall
    precision = true_positives / (true_positives + false_positives) if true_positives + false_positives > 0 else 0
    recall = true_positives / (true_positives + false_negatives) if true_positives + false_negatives > 0 else 0

    return precision, recall

# Calculate metrics for the whole dataset
precision, recall = calculate_metrics(all_detections, all_ground_truths)

# Print evaluation results
print(f"Precision: {precision:.3f}")
print(f"Recall: {recall:.3f}")
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-10-29 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7029004 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Precision: 0.000
# Recall: 0.000
